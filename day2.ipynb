# %% [markdown]
# <a href="https://colab.research.google.com/github/Hailstorm123/CDAV/blob/main/day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name =('what is your name ?')
age =("what is your age ?")
course =('what is your current course')

# %%
name = input("What is your name?")
food = input("What is your favourite food?")
sport = input("What is your favourite sport?")
# Out:
# What is your name?John
# What is your favourite food?Pizza
# What is your favourite sport?Football

# %%
print(f"Hello {name}!")
print(f"You like {food}")
print(f"Your favourite sport is {sport}")
# Out:
# Hello John!
# You like Pizza
# Your favourite sport is Football

# %%
name =input ("what is your name?" )
food =input('what is your favourite food')
sport =input("what is your favourite sport")
# Out:
# what is your name?h
# what is your favourite foodu
# what is your favourite sportj

# %%
print(f"hello {name}!")
print(f"you like {food}.")
print(f"your favourita sport is {sport}.")
# Out:
# hello h!
# you like u.
# your favourita sport is j.

# %%
name = "John"
type(name)
print(type(name))
# Out:
# <class 'str'>

# %%
 name ="fally"
 type(name)
 print(type(name))
# Out:
# <class 'str'>

# %%
y =23
x=18
print(type(y))
# Out:
# <class 'int'>

# %%
print (type(x))
# Out:
# <class 'int'>

# %%
x = 4
y = 2
print(x/y)
# Out:
# 2.0

# %%
float(10)
# Out:
# 10.0

# %%
pi =3.14
int(pi)
# Out:
# 3

# %%
str(10)
# Out:
# '10'

# %%
print(12+12)
print(10-2)
print(20/5)
print(5*2)
# Out:
# 24
# 8
# 4.0
# 10

# %%
x =10
print(type(x))
# Out:
# <class 'int'>

# %%
x =float (x)
print (type(x))
print(x)
# Out:
# <class 'float'>
# 10.0

# %%
age =input ("what is your age?")
# Out:
# what is your age?20

# %%
age ="20"
age =int(input("what is your age"))
# Out:
# what is your age19

# %% [markdown]
# # type casting
# processs of changing values from one data type to compatible data types
# use the destination data type short form as a function()

# %%
temp = float(input("what is your body temperature"))
fah = (temp*1.8) + 32
print("your body temperature in fahrenheit is",fah)
# Out:
# what is your body temperature54
# your body temperature in fahrenheit is 129.2

# %%
temp = float (input("what is your body temperature"))
fah = (temp*1.8) +32
print ("your body temperature in fahrenheit is",fah)
# Out:
# what is your body temperature37
# your body temperature in fahrenheit is 98.60000000000001

# %%
from os import MFD_HUGE_32MB
temp = float(input("what is your body temperature"))
fah = (temp*1.8) +32
print("your body temperature in fahrenheit is",fah)
# Out:
# what is your body temperature54.6
# your body temperature in fahrenheit is 130.28

# %%
y =24
z =12
print(y/z)
# Out:
# 2.0

# %%
num1 = float(input("Enter the first number:"))
num2 = float(input("Enter the second number:"))
print(f"The sum of the two number is {num1+num2}")
print(f"The difference between the two numbers is {num1-num2}")
print(f"The product of the two numbers is {num1*num2}")
print(f"the division of the two numbers is {num1/num2}")
print( f"the integer division of the two numbers is{num1%num2}")
print(f"the modulus of the two numbers is {num1//num2}")
print(f"the power of the two numbers is {num1**num2}")
# Out:
# Enter the first number:24
# Enter the second number:4
# The sum of the two number is 28.0
# The difference between the two numbers is 20.0
# The product of the two numbers is 96.0
# the division of the two numbers is 6.0
# the integer division of the two numbers is20.0
# the modulus of the two numbers is 20.0
# the power of the two numbers is 331776.0

# %%
print(20>10)
# Out:
# True

# %%
print ( 5==5)
# Out:
# True

# %%
print (5!=5)
# Out:
# False

# %%
name = input("enter your name :")
age =int (input("what is your age?" ))
course =input("enter the course u are doing :")
print("="*30)
print ("student profile")
print ("="*30)
# Out:
# enter your name :Robin
# what is your age?20
# enter the course u are doing :CDAV
# ...
# student profile
# ...

# %%
print ("="*30)
print("STUDENT PROFILE")
print ("="*30)
name  = input("enter your name :")
age  =int(input("what is your age ?"))
course =input("enter the course you are doing:")
# Out:
# ...
# STUDENT PROFILE
# ...
# enter your name :Robin
# what is your age ?20
# enter the course you are doing:CDAV

# %%
name = "robin"
age ="20"
hobby =" coding"
print ("my name is",name)
print("I am",age,"years old")
print ("my hobby is",hobby)
# Out:
# my name is robin
# I am 20 years old
# my hobby is  coding

# %%
weight = float (input("enter your weight in kilogram "))
height = float (input("enter your height in metres"))
average = (weight + height)/2
print (f"average in kilograms {average}")
# Out:
# enter your weight in kilogram 80.1
# enter your height in kilogram12.4
# average in kilograms 46.25

# %%
lenght =float (input("enter the lenght of the room in metres :"))
width = float (input("enter th width of the room in metres :"))
area =lenght * width
print(f"the area of room in metres square,{area}")
# Out:
# enter the lenght of the room in metres :40
# enter th width of the room in metres :30
# the area of room in metres square,1200.0

# %%
lenght = float (input("enter length of room in metres"))
width =float (input("enter width of room in metres"))
area =lenght * width
print(f"th area of room in metres squares,{ area}")
# Out:
# enter length of room in metres40
# enter width of room in metres24
# th area of room in metres squares,960.0
