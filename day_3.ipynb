# %% [markdown]
# <a href="https://colab.research.google.com/github/Hailstorm123/CDAV/blob/main/day_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
is_raining = True
if is_raining :
  print ("stay indoors")
# Out:
# stay indoors
# carry an umbrella

# %%
balance =55
withdrawal_amount =float( input("how much do you want to withdraw "))
if withdrawal_amount>balance :
  print("you have insufficient balance")
# Out:
# how much do you want to withdraw 100
# you have insufficient balance

# %%
balance = 1250
withdrawal_amount =float (input("how much do you want to withdraw"))
if withdrawal_amount >= balance :
                          print ("insufficient balance ")
                          print ("top up and try again")
else :
     print('withdrawal unsuccessful')
# Out:
# how much do you want to withdraw1300
# insufficient balance
# top up and try again

# %%
password =input("enter correct password")
if password== "python123":
  print ("correct password")
else:
  print("incorrect password")
# Out:
# enter correct passwordpython123
# correct password

# %%
password =input ("enter correct  password")
if password == "python123" :
  print("correct password")
else :
  print("incorrect password")
# Out:
# enter correct  passwordpython123
# correct password

# %%
marks = float(input("Enter your marks"))
if marks >=50 :
  print ("congratulation for passing")
if marks < 50:
  print("Can do better")
# Out:
# Enter your marks80
# congratulation for passing

# %%
marks =float(input("enter your marks "))
if marks >=50:
  print("congratulation for passing")
if marks < 50:
  print("changamka")
# Out:
# enter your marks 45
# changamka

# %%
is_raining  = True
if is_raining :
  print("stay indoors")
else :
  print("carry  an umbrella")
# Out:
# stay indoors

# %%
is_raining  = input("if it's rsining , type 1 .if not type 2")
is_cloudy = input("if it's cloudy , type 1. if not type 2")
if is_raining == "1":
  print("use an umbrella")
elif is_cloudy == "1":
  print("carry an umbrella")
else:
  print("you do not need an umbrella")
# Out:
# if it's rsining , type 1 .if not type 22
# if it's cloudy , type 1. if not type 22
# you do not need an umbrella

# %%
a=1
b=2
c=3
print(a==b and b==c)
print(a<b or b>c )
print (a<b and b>c )
# Out:
# False
# True
# False

# %%
from concurrent.futures.thread import ThreadPoolExecutor
# write a program that takes value from the user ,the program should print
number = int(input("enter the number"))
if number % 2 == 0 and number % 3 == 0:
  print(f"{number} is divisible by 2 and 3")
elif number % 2 == 0:
  print(f"{number} is divisible by 2")
elif number % 3 == 0:
  print(f"{number} is divisible by 3")
else:
  print(f"{number} is not divisble by 2 or 3")
# Out:
# enter the number30
# 30 is divisible by 2 and 3

# %%
# write a program that takes value from the user , the program should print
number = int(input("enter the number"))
if number % 2 == 0 and number % 3 == 0:
  print(f"{number} is divisible by 2 and 3")
elif number % 2 == 0:
  print(f"{number} is divisible by 2")
elif number % 3 == 0:
  print(f"{number} is divisible by 3")
else :
  print(f"{number} is not divisible by 2 or 3")
# Out:
# enter the number0
# 0 is divisible by 2 and 3

# %%
val =int (input("enter the value"))
if val%2 ==0 and val%3 ==0:
  print(f"{val} is divisible by both 2 and 3")
elif val%2 ==0:
  print(f"{val} is divisible by 2")
elif val%3 ==0:
  print(f"{val} is divisible by 3")
else:
  print(f"{val} is not divisible by 2 or 3")
# Out:
# enter the value24
# 24 is divisible by both 2 and 3

# %%
# grade converter that tells range of marks
grade = input("Enter your grade")
if grade == "A" :
  print("you scored above 80")
elif grade == "B":
  print("your score above 70")
elif grade =="C" :
  print("your score above60")
elif grade == "D":
  print("your score above 50")
else :
  print ("grade entered is invalid")
# Out:
# Enter your grade45
# grade entered is invalid

# %%
n = int(input( "enter a positive integer"))
total =int  ((n*(n+1))/2 )
print(f"the sum of all integer from 0 to {n} is {total} " )
# Out:
# enter a positive integer2
# the sum of all integer from 0 to 2 is 3
