# %% [markdown]
# <a href="https://colab.research.google.com/github/Hailstorm123/CDAV/blob/main/xp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("I am " , 20 , "years old")
# Out:
# I am  20 years old

# %%
# write a single_line comment
#comment out this line so it does not run :
print ( " this should not run ")
# add a multiline comment
# Out:
#  this should not run

# %%
# variables
x = 5
y = "John"
print ( x )
print ( y )
# Out:
# 5
# John

# %%
x = 4  # x is of type int
x ="Sally"  # is now of type str
print ( x )
# Out:
# Sally

# %%
a = 4
A = "Sally"
print ( a )
print ( A )
# A will not overwrite a
# Out:
# 4
# Sally

# %%
x , y , z = "orange" , "banana" , "cherry"
print ( x )
print ( y )
print ( z )
# Out:
# orange
# banana
# cherry

# %%
fruits =[ "apple" , "banana" , "cherry" ]
x , y ,z = fruits
print ( x )
print ( y )
print ( z )
# Out:
# apple
# banana
# cherry

# %%
x = 5
y = " John "
print ( x , y )
# Out:
# 5  John

# %%
print ( 'hello' , 'world')
# Out:
# hello world

# %%
a = 'hello'
b = 'world'
print ( a+b )
# Out:
# helloworld

# %%
x = "awesome"
def myfunc () :
  print ( "python is " + x )
myfunc ()
# Out:
# python is awesome

# %%
x = "awesome"
def myfunc () :
  print ("Python is " + x)
myfunc()
x = "fantastic"
myfunc()
print("Python is " + x )
# Out:
# Python is awesome
# Python is fantastic
# Python is fantastic

# %%
for x in "banana" :
  print ( x )
# Out:
# b
# a
# n
# a
# n
# a

# %%
a = "hello , world"
print (len( a))
# Out:
# 13

# %%
txt = " the best things in life are free ! "
print ("free" in txt )
# Out:
# True

# %%
txt = " the best things in life are free ! "
if "free" in txt :
  print (" yes , 'free' is present ")
# Out:
#  yes , 'free' is present

# %%
txt = " the best things in life are free ! "
print ("expensive" not in txt )
# Out:
# True

# %%
txt = " the best things in life are free ! "
if "expensive" not in txt :
  print (" no , 'expensive' is not present ")
# Out:
#  no , 'expensive' is not present

# %%
b = " hello world "
print ( b [2:5] )
# Out:
# ell

# %%
b = " hello , world ! "
print (b[:5])
# Out:
#  hell

# %%
b = " hello , world ! "
print (b[2:])
# Out:
# ello , world !

# %%
b = " hello , world ! "
print (b[-5:-2])
# Out:
# ld
